# %%
import pickle
import os 
os.environ["OPENAI_API_KEY"] = "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"

# %%
result = pickle.load(open('data.pkl','rb'))

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
text_splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=800,
    chunk_overlap = 40,
    length_function = len,
)
texts = text_splitter.split_text(result)

# %%
len(result)
# Out:
# 38349

# %%
embeddings = OpenAIEmbeddings()

# %%
document_search= FAISS.from_texts(texts,embeddings)

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(),chain_type="stuff")

# %%
query = "Summarize this meeting"
docs = document_search.similarity_search(query)

# %%
ans = chain.run(input_documents = docs,question=query)
print(ans)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ans = chain.run(input_documents = docs,question=query)
#       2 print(ans)
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\base.py:516, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     511     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     512         _output_key
#     513     ]
#     515 if kwargs and not args:
# --> 516     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     517         _output_key
#     518     ]
#     520 if not kwargs and not args:
#     521     raise ValueError(
#     522         "`run` supported with either positional arguments or keyword arguments,"
#     523         " but none were provided."
#     524     )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\base.py:316, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     314 except BaseException as e:
#     315     run_manager.on_chain_error(e)
# --> 316     raise e
#     317 run_manager.on_chain_end(outputs)
#     318 final_outputs: Dict[str, Any] = self.prep_outputs(
#     319     inputs, outputs, return_only_outputs
#     320 )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\base.py:310, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     303 run_manager = callback_manager.on_chain_start(
#     304     dumpd(self),
#     305     inputs,
#     306     name=run_name,
#     307 )
#     308 try:
#     309     outputs = (
# --> 310         self._call(inputs, run_manager=run_manager)
#     311         if new_arg_supported
#     312         else self._call(inputs)
#     313     )
#     314 except BaseException as e:
#     315     run_manager.on_chain_error(e)
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\combine_documents\base.py:136, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     134 # Other keys are assumed to be needed for LLM prediction
#     135 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 136 output, extra_return_dict = self.combine_docs(
#     137     docs, callbacks=_run_manager.get_child(), **other_keys
#     138 )
#     139 extra_return_dict[self.output_key] = output
#     140 return extra_return_dict
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\combine_documents\stuff.py:244, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     242 inputs = self._get_inputs(docs, **kwargs)
#     243 # Call predict on the LLM.
# --> 244 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\llm.py:293, in LLMChain.predict(self, callbacks, **kwargs)
#     278 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     279     """Format prompt with kwargs and pass to LLM.
#     280
#     281     Args:
#    (...)
#     291             completion = llm.predict(adjective="funny")
#     292     """
# --> 293     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\base.py:316, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     314 except BaseException as e:
#     315     run_manager.on_chain_error(e)
# --> 316     raise e
#     317 run_manager.on_chain_end(outputs)
#     318 final_outputs: Dict[str, Any] = self.prep_outputs(
#     319     inputs, outputs, return_only_outputs
#     320 )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\base.py:310, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     303 run_manager = callback_manager.on_chain_start(
#     304     dumpd(self),
#     305     inputs,
#     306     name=run_name,
#     307 )
#     308 try:
#     309     outputs = (
# --> 310         self._call(inputs, run_manager=run_manager)
#     311         if new_arg_supported
#     312         else self._call(inputs)
#     313     )
#     314 except BaseException as e:
#     315     run_manager.on_chain_error(e)
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\llm.py:103, in LLMChain._call(self, inputs, run_manager)
#      98 def _call(
#      99     self,
#     100     inputs: Dict[str, Any],
#     101     run_manager: Optional[CallbackManagerForChainRun] = None,
#     102 ) -> Dict[str, str]:
# --> 103     response = self.generate([inputs], run_manager=run_manager)
#     104     return self.create_outputs(response)[0]
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain\chains\llm.py:115, in LLMChain.generate(self, input_list, run_manager)
#     113 callbacks = run_manager.get_child() if run_manager else None
#     114 if isinstance(self.llm, BaseLanguageModel):
# --> 115     return self.llm.generate_prompt(
#     116         prompts,
#     117         stop,
#     118         callbacks=callbacks,
#     119         **self.llm_kwargs,
#     120     )
#     121 else:
#     122     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     123         cast(List, prompts), {"callbacks": callbacks}
#     124     )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_core\language_models\llms.py:521, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     513 def generate_prompt(
#     514     self,
#     515     prompts: List[PromptValue],
#    (...)
#     518     **kwargs: Any,
#     519 ) -> LLMResult:
#     520     prompt_strings = [p.to_string() for p in prompts]
# --> 521     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_core\language_models\llms.py:671, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     655         raise ValueError(
#     656             "Asked to cache, but no cache found at `langchain.cache`."
#     657         )
#     658     run_managers = [
#     659         callback_manager.on_llm_start(
#     660             dumpd(self),
#    (...)
#     669         )
#     670     ]
# --> 671     output = self._generate_helper(
#     672         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     673     )
#     674     return output
#     675 if len(missing_prompts) > 0:
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_core\language_models\llms.py:558, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     556     for run_manager in run_managers:
#     557         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 558     raise e
#     559 flattened_outputs = output.flatten()
#     560 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_core\language_models\llms.py:545, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     535 def _generate_helper(
#     536     self,
#     537     prompts: List[str],
#    (...)
#     541     **kwargs: Any,
#     542 ) -> LLMResult:
#     543     try:
#     544         output = (
# --> 545             self._generate(
#     546                 prompts,
#     547                 stop=stop,
#     548                 # TODO: support multiple run managers
#     549                 run_manager=run_managers[0] if run_managers else None,
#     550                 **kwargs,
#     551             )
#     552             if new_arg_supported
#     553             else self._generate(prompts, stop=stop)
#     554         )
#     555     except BaseException as e:
#     556         for run_manager in run_managers:
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_community\llms\openai.py:459, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     447     choices.append(
#     448         {
#     449             "text": generation.text,
#    (...)
#     456         }
#     457     )
#     458 else:
# --> 459     response = completion_with_retry(
#     460         self, prompt=_prompts, run_manager=run_manager, **params
#     461     )
#     462     if not isinstance(response, dict):
#     463         # V1 client returns the response in an PyDantic object instead of
#     464         # dict. For the transition period, we deep convert it to dict.
#     465         response = response.dict()
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\langchain_community\llms\openai.py:114, in completion_with_retry(llm, run_manager, **kwargs)
#     112 """Use tenacity to retry the completion call."""
#     113 if is_openai_v1():
# --> 114     return llm.client.create(**kwargs)
#     116 retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#     118 @retry_decorator
#     119 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\openai\_utils\_utils.py:272, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     270             msg = f"Missing required argument: {quote(missing[0])}"
#     271     raise TypeError(msg)
# --> 272 return func(*args, **kwargs)
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\openai\resources\completions.py:562, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     520 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     521 def create(
#     522     self,
#    (...)
#     560     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     561 ) -> Completion | Stream[Completion]:
# --> 562     return self._post(
#     563         "/completions",
#     564         body=maybe_transform(
#     565             {
#     566                 "model": model,
#     567                 "prompt": prompt,
#     568                 "best_of": best_of,
#     569                 "echo": echo,
#     570                 "frequency_penalty": frequency_penalty,
#     571                 "logit_bias": logit_bias,
#     572                 "logprobs": logprobs,
#     573                 "max_tokens": max_tokens,
#     574                 "n": n,
#     575                 "presence_penalty": presence_penalty,
#     576                 "seed": seed,
#     577                 "stop": stop,
#     578                 "stream": stream,
#     579                 "suffix": suffix,
#     580                 "temperature": temperature,
#     581                 "top_p": top_p,
#     582                 "user": user,
#     583             },
#     584             completion_create_params.CompletionCreateParams,
#     585         ),
#     586         options=make_request_options(
#     587             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     588         ),
#     589         cast_to=Completion,
#     590         stream=stream or False,
#     591         stream_cls=Stream[Completion],
#     592     )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\openai\_base_client.py:1088, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1074 def post(
#    1075     self,
#    1076     path: str,
#    (...)
#    1083     stream_cls: type[_StreamT] | None = None,
#    1084 ) -> ResponseT | _StreamT:
#    1085     opts = FinalRequestOptions.construct(
#    1086         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087     )
# -> 1088     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\openai\_base_client.py:853, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     844 def request(
#     845     self,
#     846     cast_to: Type[ResponseT],
#    (...)
#     851     stream_cls: type[_StreamT] | None = None,
#     852 ) -> ResponseT | _StreamT:
# --> 853     return self._request(
#     854         cast_to=cast_to,
#     855         options=options,
#     856         stream=stream,
#     857         stream_cls=stream_cls,
#     858         remaining_retries=remaining_retries,
#     859     )
#
# File c:\Users\Dhana\Documents\Craftech\lang-chain\lang-env\lib\site-packages\openai\_base_client.py:930, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927     if not err.response.is_closed:
#     928         err.response.read()
# --> 930     raise self._make_status_error_from_response(err.response) from None
#     932 return self._process_response(
#     933     cast_to=cast_to,
#     934     options=options,
#    (...)
#     937     stream_cls=stream_cls,
#     938 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 4097 tokens, however you requested 8469 tokens (8213 in your prompt; 256 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
